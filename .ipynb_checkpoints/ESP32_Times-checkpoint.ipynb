# %%
%serialconnect to --port=/dev/ttyUSB0 --baud=115200
# Out:
# Connecting to --port=/dev/ttyUSB0 --baud=115200
# Ready.

# %%
import machine
 
interruptCounter = 0
totalInterruptsCounter = 0
 
timer = machine.Timer(1)  
print(timer.value())
 
def handleInterrupt(timer):
    global interruptCounter
    interruptCounter = interruptCounter+1
    print('Interupt Timer: ', timer.value())
#     print(dir(timer))
 
timer.init(period=10, mode=machine.Timer.PERIODIC, callback=handleInterrupt)
# print(timer)
 
while True:
#     print('Timer: ', timer.value())
    if interruptCounter>0:
#         print(timer.value())
        state = machine.disable_irq()
        interruptCounter = interruptCounter-1
        machine.enable_irq(state)
 
        totalInterruptsCounter = totalInterruptsCounter+1
        print("Interrupt has occurred: " + str(totalInterruptsCounter))
# Out:
# 0
# Interupt Timer:  0
# ['__class__', 'value', '__del__', 'ONE_SHOT', 'PERIODIC', 'deinit', 'init']
# Interrupt has occurred: 1
# Interupt Timer:  0
# ['__class__', 'value', '__del__', 'ONE_SHOT', 'PERIODIC', 'deinit', 'init']
# Interrupt has occurred: 2
# Interupt Timer:  0
# ['__class__', 'value', '__del__', 'ONE_SHOT', 'PERIODIC', 'deinit', 'init']
# Interrupt has occurred: 3
# Interupt Timer:  0
# ['__class__', 'value', '__del__', 'ONE_SHOT', 'PERIODIC', 'deinit', 'init']
# Interrupt has occurred: 4
# Interupt Timer:  0
# ['__class__', 'value', '__del__', 'ONE_SHOT', 'PERIODIC', 'deinit', 'init']
# Interrupt has occurred: 5
# Interupt Timer:  0
# ['__class__', 'value', '__del__', 'ONE_SHOT', 'PERIODIC', 'deinit', 'init']
# Interrupt has occurred: 6
# Interupt Timer:  0
# ['__class__', 'value', '__del__', 'ONE_SHOT', 'PERIODIC', 'deinit', 'init']
# Interrupt has occurred: 7
# Interupt Timer:  0
# ['__class__', 'value', '__del__', 'ONE_SHOT', 'PERIODIC', 'deinit', 'init']
# ...

# %% [markdown]
# <h1>Machine Reset</h1>
# <p>
#      Reset cause:s
# <ol>
#     <li> machine.PWRON_RE</li>
#     <li> machine.HARD_RESET</li>
#     <li> machine.WDT_RESET</li>
#     <li> machine.DEEPSLEEP_RESET</li>
#     <li> machine.SOFT_RESET</li>
# </ol>
# </p>

# %%
import machine
print(machine.reset_cause())
print(machine.SOFT_RESET)
# Out:
# No serial connected
#   %serialconnect to connect
#   %esptool to flash the device
#   %lsmagic to list commands

# %%
machine.soft_reset()
# Out:
# No serial connected
#   %serialconnect to connect
#   %esptool to flash the device
#   %lsmagic to list commands

# %%
machine.reset()
# Out:
# No serial connected
#   %serialconnect to connect
#   %esptool to flash the device
#   %lsmagic to list commands
